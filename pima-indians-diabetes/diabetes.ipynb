# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/9s/5vz1zfb95wz07q4_m6h5bg8w0000gn/T/tmptcrh8b9n
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/9s/5vz1zfb95wz07q4_m6h5bg8w0000gn/T/tmptcrh8b9n', '_tf_random_seed': 1, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/9s/5vz1zfb95wz07q4_m6h5bg8w0000gn/T/tmptcrh8b9n/model.ckpt.
# INFO:tensorflow:loss = 6.93147, step = 1
# INFO:tensorflow:global_step/sec: 112.342
# INFO:tensorflow:loss = 4.55623, step = 101 (0.904 sec)
# INFO:tensorflow:global_step/sec: 162.603
# INFO:tensorflow:loss = 4.95407, step = 201 (0.605 sec)
# INFO:tensorflow:global_step/sec: 137.741
# INFO:tensorflow:loss = 7.22656, step = 301 (0.735 sec)
# INFO:tensorflow:global_step/sec: 133.546
# INFO:tensorflow:loss = 4.07926, step = 401 (0.741 sec)
# INFO:tensorflow:global_step/sec: 98.318
# INFO:tensorflow:loss = 5.96602, step = 501 (1.018 sec)
# INFO:tensorflow:global_step/sec: 112.16
# INFO:tensorflow:loss = 4.93299, step = 601 (0.896 sec)
# INFO:tensorflow:global_step/sec: 122.528
# INFO:tensorflow:loss = 4.52872, step = 701 (0.814 sec)
# INFO:tensorflow:global_step/sec: 106.779
# INFO:tensorflow:loss = 5.7533, step = 801 (0.932 sec)
# INFO:tensorflow:global_step/sec: 115.303
# INFO:tensorflow:loss = 4.55146, step = 901 (0.871 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/9s/5vz1zfb95wz07q4_m6h5bg8w0000gn/T/tmptcrh8b9n/model.ckpt.
# INFO:tensorflow:Loss for final step: 6.02075.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-10-29-05:15:44
# INFO:tensorflow:Restoring parameters from /var/folders/9s/5vz1zfb95wz07q4_m6h5bg8w0000gn/T/tmptcrh8b9n/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-10-29-05:15:47
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.728346, accuracy_baseline = 0.65748, auc = 0.784844, auc_precision_recall = 0.621917, average_loss = 0.536248, global_step = 1000, label/mean = 0.34252, loss = 5.23873, prediction/mean = 0.389012

# %%
results
# Out:
# {'accuracy': 0.72834647,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.7848441,
#  'auc_precision_recall': 0.62191695,
#  'average_loss': 0.53624803,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.2387309,
#  'prediction/mean': 0.38901213}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Restoring parameters from /var/folders/9s/5vz1zfb95wz07q4_m6h5bg8w0000gn/T/tmptcrh8b9n/model.ckpt-1000
# [{'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.56231594], dtype=float32),
#   'logits': array([ 0.25056648], dtype=float32),
#   'probabilities': array([ 0.43768406,  0.56231594], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.64104164], dtype=float32),
#   'logits': array([ 0.57988799], dtype=float32),
#   'probabilities': array([ 0.35895836,  0.64104164], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41160512], dtype=float32),
#   'logits': array([-0.35733378], dtype=float32),
#   'probabilities': array([ 0.58839488,  0.41160512], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35520944], dtype=float32),
#   'logits': array([-0.59621781], dtype=float32),
#   'probabilities': array([ 0.64479053,  0.35520947], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15942098], dtype=float32),
#   'logits': array([-1.66254258], dtype=float32),
#   'probabilities': array([ 0.84057903,  0.15942098], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73526168], dtype=float32),
#   'logits': array([ 1.02148449], dtype=float32),
#   'probabilities': array([ 0.26473835,  0.73526168], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.6049816], dtype=float32),
#   'logits': array([ 0.42626584], dtype=float32),
#   'probabilities': array([ 0.39501837,  0.6049816 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3876057], dtype=float32),
#   'logits': array([-0.4573878], dtype=float32),
#   'probabilities': array([ 0.61239433,  0.3876057 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27764875], dtype=float32),
#   'logits': array([-0.95615476], dtype=float32),
#   'probabilities': array([ 0.72235125,  0.27764872], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25728661], dtype=float32),
#   'logits': array([-1.06011951], dtype=float32),
#   'probabilities': array([ 0.74271333,  0.25728661], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13399349], dtype=float32),
#   'logits': array([-1.86610126], dtype=float32),
#   'probabilities': array([ 0.86600649,  0.13399349], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16412576], dtype=float32),
#   'logits': array([-1.62784517], dtype=float32),
#   'probabilities': array([ 0.8358742 ,  0.16412576], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30907241], dtype=float32),
#   'logits': array([-0.80445951], dtype=float32),
#   'probabilities': array([ 0.69092762,  0.30907241], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.6246323], dtype=float32),
#   'logits': array([ 0.50925696], dtype=float32),
#   'probabilities': array([ 0.37536776,  0.6246323 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1836912], dtype=float32),
#   'logits': array([-1.49153662], dtype=float32),
#   'probabilities': array([ 0.8163088,  0.1836912], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3625553], dtype=float32),
#   'logits': array([-0.56429052], dtype=float32),
#   'probabilities': array([ 0.63744473,  0.36255533], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40306127], dtype=float32),
#   'logits': array([-0.39272588], dtype=float32),
#   'probabilities': array([ 0.59693873,  0.40306127], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13529314], dtype=float32),
#   'logits': array([-1.85494673], dtype=float32),
#   'probabilities': array([ 0.86470687,  0.13529314], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37826312], dtype=float32),
#   'logits': array([-0.4969269], dtype=float32),
#   'probabilities': array([ 0.62173688,  0.37826315], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14934754], dtype=float32),
#   'logits': array([-1.7397275], dtype=float32),
#   'probabilities': array([ 0.85065246,  0.14934756], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24532226], dtype=float32),
#   'logits': array([-1.12371814], dtype=float32),
#   'probabilities': array([ 0.75467771,  0.24532224], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33946154], dtype=float32),
#   'logits': array([-0.66569471], dtype=float32),
#   'probabilities': array([ 0.66053849,  0.33946154], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.71085066], dtype=float32),
#   'logits': array([ 0.89951921], dtype=float32),
#   'probabilities': array([ 0.28914931,  0.71085066], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23490232], dtype=float32),
#   'logits': array([-1.1808337], dtype=float32),
#   'probabilities': array([ 0.76509768,  0.23490232], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19333896], dtype=float32),
#   'logits': array([-1.42845857], dtype=float32),
#   'probabilities': array([ 0.80666101,  0.19333896], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.78402311], dtype=float32),
#   'logits': array([ 1.28926718], dtype=float32),
#   'probabilities': array([ 0.21597686,  0.78402311], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2028258], dtype=float32),
#   'logits': array([-1.36872578], dtype=float32),
#   'probabilities': array([ 0.79717416,  0.20282578], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33623958], dtype=float32),
#   'logits': array([-0.68009734], dtype=float32),
#   'probabilities': array([ 0.66376042,  0.33623958], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10413644], dtype=float32),
#   'logits': array([-2.15208626], dtype=float32),
#   'probabilities': array([ 0.89586353,  0.10413643], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.63539809], dtype=float32),
#   'logits': array([ 0.55544567], dtype=float32),
#   'probabilities': array([ 0.36460188,  0.63539809], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.94799525], dtype=float32),
#   'logits': array([ 2.90301418], dtype=float32),
#   'probabilities': array([ 0.05200476,  0.94799525], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42586595], dtype=float32),
#   'logits': array([-0.2987383], dtype=float32),
#   'probabilities': array([ 0.57413405,  0.42586592], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34097993], dtype=float32),
#   'logits': array([-0.65893036], dtype=float32),
#   'probabilities': array([ 0.65902001,  0.3409799 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59362829], dtype=float32),
#   'logits': array([ 0.37898505], dtype=float32),
#   'probabilities': array([ 0.40637171,  0.59362829], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26295111], dtype=float32),
#   'logits': array([-1.03068614], dtype=float32),
#   'probabilities': array([ 0.73704892,  0.26295111], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40310428], dtype=float32),
#   'logits': array([-0.39254719], dtype=float32),
#   'probabilities': array([ 0.59689575,  0.40310428], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.56104243], dtype=float32),
#   'logits': array([ 0.24539387], dtype=float32),
#   'probabilities': array([ 0.43895754,  0.56104243], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.66532999], dtype=float32),
#   'logits': array([ 0.68713796], dtype=float32),
#   'probabilities': array([ 0.33467007,  0.66532999], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.7801494], dtype=float32),
#   'logits': array([ 1.26653731], dtype=float32),
#   'probabilities': array([ 0.21985058,  0.7801494 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33708787], dtype=float32),
#   'logits': array([-0.67629886], dtype=float32),
#   'probabilities': array([ 0.66291213,  0.33708784], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20607249], dtype=float32),
#   'logits': array([-1.34876406], dtype=float32),
#   'probabilities': array([ 0.79392749,  0.20607249], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54808497], dtype=float32),
#   'logits': array([ 0.19293618], dtype=float32),
#   'probabilities': array([ 0.45191503,  0.54808497], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16247141], dtype=float32),
#   'logits': array([-1.63995337], dtype=float32),
#   'probabilities': array([ 0.83752865,  0.16247141], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5581907], dtype=float32),
#   'logits': array([ 0.23382235], dtype=float32),
#   'probabilities': array([ 0.4418093,  0.5581907], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14895569], dtype=float32),
#   'logits': array([-1.74281526], dtype=float32),
#   'probabilities': array([ 0.85104436,  0.1489557 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10671154], dtype=float32),
#   'logits': array([-2.12478018], dtype=float32),
#   'probabilities': array([ 0.89328843,  0.10671154], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62523228], dtype=float32),
#   'logits': array([ 0.51181686], dtype=float32),
#   'probabilities': array([ 0.37476769,  0.62523228], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20452632], dtype=float32),
#   'logits': array([-1.35824108], dtype=float32),
#   'probabilities': array([ 0.79547369,  0.20452634], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22115968], dtype=float32),
#   'logits': array([-1.25892115], dtype=float32),
#   'probabilities': array([ 0.7788403 ,  0.22115967], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11504401], dtype=float32),
#   'logits': array([-2.04022312], dtype=float32),
#   'probabilities': array([ 0.88495606,  0.11504402], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18345805], dtype=float32),
#   'logits': array([-1.4930923], dtype=float32),
#   'probabilities': array([ 0.81654191,  0.18345805], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26171708], dtype=float32),
#   'logits': array([-1.03706312], dtype=float32),
#   'probabilities': array([ 0.73828292,  0.26171708], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27244058], dtype=float32),
#   'logits': array([-0.98227519], dtype=float32),
#   'probabilities': array([ 0.72755939,  0.27244055], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40745085], dtype=float32),
#   'logits': array([-0.37451351], dtype=float32),
#   'probabilities': array([ 0.59254915,  0.40745085], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14289437], dtype=float32),
#   'logits': array([-1.79145551], dtype=float32),
#   'probabilities': array([ 0.85710567,  0.14289437], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23884141], dtype=float32),
#   'logits': array([-1.159042], dtype=float32),
#   'probabilities': array([ 0.76115859,  0.2388414 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23144108], dtype=float32),
#   'logits': array([-1.20019197], dtype=float32),
#   'probabilities': array([ 0.76855892,  0.23144107], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2408482], dtype=float32),
#   'logits': array([-1.14803493], dtype=float32),
#   'probabilities': array([ 0.75915182,  0.24084821], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52272272], dtype=float32),
#   'logits': array([ 0.09095359], dtype=float32),
#   'probabilities': array([ 0.47727725,  0.52272272], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1765468], dtype=float32),
#   'logits': array([-1.53992069], dtype=float32),
#   'probabilities': array([ 0.82345319,  0.1765468 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26157561], dtype=float32),
#   'logits': array([-1.03779542], dtype=float32),
#   'probabilities': array([ 0.73842442,  0.26157558], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.69544774], dtype=float32),
#   'logits': array([ 0.82571316], dtype=float32),
#   'probabilities': array([ 0.30455226,  0.69544774], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.6669088], dtype=float32),
#   'logits': array([ 0.69423711], dtype=float32),
#   'probabilities': array([ 0.33309117,  0.6669088 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53985494], dtype=float32),
#   'logits': array([ 0.15975857], dtype=float32),
#   'probabilities': array([ 0.46014512,  0.53985494], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38359222], dtype=float32),
#   'logits': array([-0.47432876], dtype=float32),
#   'probabilities': array([ 0.61640781,  0.38359222], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50718474], dtype=float32),
#   'logits': array([ 0.02874076], dtype=float32),
#   'probabilities': array([ 0.49281535,  0.50718474], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19063067], dtype=float32),
#   'logits': array([-1.44591749], dtype=float32),
#   'probabilities': array([ 0.80936933,  0.19063066], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2120726], dtype=float32),
#   'logits': array([-1.31247723], dtype=float32),
#   'probabilities': array([ 0.78792745,  0.21207261], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17264155], dtype=float32),
#   'logits': array([-1.56702054], dtype=float32),
#   'probabilities': array([ 0.82735842,  0.17264155], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14182808], dtype=float32),
#   'logits': array([-1.8001889], dtype=float32),
#   'probabilities': array([ 0.85817188,  0.14182808], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61257505], dtype=float32),
#   'logits': array([ 0.45814955], dtype=float32),
#   'probabilities': array([ 0.38742489,  0.61257505], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24744526], dtype=float32),
#   'logits': array([-1.11228442], dtype=float32),
#   'probabilities': array([ 0.75255471,  0.24744523], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44366422], dtype=float32),
#   'logits': array([-0.22630394], dtype=float32),
#   'probabilities': array([ 0.55633575,  0.44366422], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61312604], dtype=float32),
#   'logits': array([ 0.46047163], dtype=float32),
#   'probabilities': array([ 0.38687393,  0.61312604], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33094189], dtype=float32),
#   'logits': array([-0.70392823], dtype=float32),
#   'probabilities': array([ 0.66905814,  0.33094186], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67979491], dtype=float32),
#   'logits': array([ 0.75282931], dtype=float32),
#   'probabilities': array([ 0.32020512,  0.67979491], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13408832], dtype=float32),
#   'logits': array([-1.8652842], dtype=float32),
#   'probabilities': array([ 0.86591172,  0.13408834], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.63300902], dtype=float32),
#   'logits': array([ 0.54514742], dtype=float32),
#   'probabilities': array([ 0.36699098,  0.63300902], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1311291], dtype=float32),
#   'logits': array([-1.89101219], dtype=float32),
#   'probabilities': array([ 0.86887091,  0.1311291 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.56290501], dtype=float32),
#   'logits': array([ 0.25296032], dtype=float32),
#   'probabilities': array([ 0.43709499,  0.56290501], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36385369], dtype=float32),
#   'logits': array([-0.55867678], dtype=float32),
#   'probabilities': array([ 0.63614631,  0.36385366], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17331961], dtype=float32),
#   'logits': array([-1.56228077], dtype=float32),
#   'probabilities': array([ 0.82668042,  0.17331962], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.58979988], dtype=float32),
#   'logits': array([ 0.36313808], dtype=float32),
#   'probabilities': array([ 0.41020012,  0.58979988], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60822195], dtype=float32),
#   'logits': array([ 0.43984437], dtype=float32),
#   'probabilities': array([ 0.39177805,  0.60822195], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57276821], dtype=float32),
#   'logits': array([ 0.29315436], dtype=float32),
#   'probabilities': array([ 0.42723179,  0.57276821], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1901827], dtype=float32),
#   'logits': array([-1.44882345], dtype=float32),
#   'probabilities': array([ 0.80981725,  0.19018269], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34187296], dtype=float32),
#   'logits': array([-0.65495878], dtype=float32),
#   'probabilities': array([ 0.65812701,  0.34187296], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16038367], dtype=float32),
#   'logits': array([-1.6553762], dtype=float32),
#   'probabilities': array([ 0.8396163 ,  0.16038367], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73966223], dtype=float32),
#   'logits': array([ 1.04421389], dtype=float32),
#   'probabilities': array([ 0.26033774,  0.73966223], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.82980967], dtype=float32),
#   'logits': array([ 1.58427894], dtype=float32),
#   'probabilities': array([ 0.17019033,  0.82980967], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.65563524], dtype=float32),
#   'logits': array([ 0.64390337], dtype=float32),
#   'probabilities': array([ 0.34436467,  0.65563524], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23211607], dtype=float32),
#   'logits': array([-1.196401], dtype=float32),
#   'probabilities': array([ 0.7678839 ,  0.23211606], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44371441], dtype=float32),
#   'logits': array([-0.22610074], dtype=float32),
#   'probabilities': array([ 0.55628562,  0.44371438], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38513756], dtype=float32),
#   'logits': array([-0.46779799], dtype=float32),
#   'probabilities': array([ 0.61486244,  0.38513756], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4866848], dtype=float32),
#   'logits': array([-0.05327332], dtype=float32),
#   'probabilities': array([ 0.5133152 ,  0.48668483], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34951535], dtype=float32),
#   'logits': array([-0.62117028], dtype=float32),
#   'probabilities': array([ 0.65048468,  0.34951535], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49956837], dtype=float32),
#   'logits': array([-0.00172651], dtype=float32),
#   'probabilities': array([ 0.5004316 ,  0.49956834], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16552199], dtype=float32),
#   'logits': array([-1.61770236], dtype=float32),
#   'probabilities': array([ 0.83447802,  0.16552198], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59158915], dtype=float32),
#   'logits': array([ 0.37053883], dtype=float32),
#   'probabilities': array([ 0.40841079,  0.59158915], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59823614], dtype=float32),
#   'logits': array([ 0.398121], dtype=float32),
#   'probabilities': array([ 0.40176392,  0.59823614], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26307559], dtype=float32),
#   'logits': array([-1.03004384], dtype=float32),
#   'probabilities': array([ 0.73692441,  0.26307559], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19070505], dtype=float32),
#   'logits': array([-1.4454354], dtype=float32),
#   'probabilities': array([ 0.809295  ,  0.19070506], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19986357], dtype=float32),
#   'logits': array([-1.38714731], dtype=float32),
#   'probabilities': array([ 0.80013645,  0.19986357], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30669978], dtype=float32),
#   'logits': array([-0.81559372], dtype=float32),
#   'probabilities': array([ 0.69330019,  0.30669978], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40794131], dtype=float32),
#   'logits': array([-0.37248248], dtype=float32),
#   'probabilities': array([ 0.59205872,  0.40794131], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1471723], dtype=float32),
#   'logits': array([-1.75695348], dtype=float32),
#   'probabilities': array([ 0.85282773,  0.14717232], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33049142], dtype=float32),
#   'logits': array([-0.70596331], dtype=float32),
#   'probabilities': array([ 0.66950858,  0.33049142], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23552869], dtype=float32),
#   'logits': array([-1.17735171], dtype=float32),
#   'probabilities': array([ 0.76447129,  0.23552869], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10038425], dtype=float32),
#   'logits': array([-2.19296241], dtype=float32),
#   'probabilities': array([ 0.89961571,  0.10038425], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12964578], dtype=float32),
#   'logits': array([-1.90409434], dtype=float32),
#   'probabilities': array([ 0.87035424,  0.12964578], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.76060665], dtype=float32),
#   'logits': array([ 1.15600812], dtype=float32),
#   'probabilities': array([ 0.2393934 ,  0.76060665], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20267269], dtype=float32),
#   'logits': array([-1.36967301], dtype=float32),
#   'probabilities': array([ 0.79732728,  0.20267266], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13916072], dtype=float32),
#   'logits': array([-1.82227838], dtype=float32),
#   'probabilities': array([ 0.86083931,  0.13916072], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14629579], dtype=float32),
#   'logits': array([-1.76395428], dtype=float32),
#   'probabilities': array([ 0.85370421,  0.14629579], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51115727], dtype=float32),
#   'logits': array([ 0.04463661], dtype=float32),
#   'probabilities': array([ 0.4888427 ,  0.51115727], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49546835], dtype=float32),
#   'logits': array([-0.0181272], dtype=float32),
#   'probabilities': array([ 0.50453168,  0.49546832], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27035305], dtype=float32),
#   'logits': array([-0.99283206], dtype=float32),
#   'probabilities': array([ 0.72964698,  0.27035305], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.45145863], dtype=float32),
#   'logits': array([-0.19477892], dtype=float32),
#   'probabilities': array([ 0.54854137,  0.45145863], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19806197], dtype=float32),
#   'logits': array([-1.39845145], dtype=float32),
#   'probabilities': array([ 0.80193806,  0.19806197], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24858281], dtype=float32),
#   'logits': array([-1.10618508], dtype=float32),
#   'probabilities': array([ 0.75141716,  0.24858277], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53218019], dtype=float32),
#   'logits': array([ 0.12889898], dtype=float32),
#   'probabilities': array([ 0.46781978,  0.53218019], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.48907143], dtype=float32),
#   'logits': array([-0.0437212], dtype=float32),
#   'probabilities': array([ 0.51092857,  0.48907146], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15090108], dtype=float32),
#   'logits': array([-1.72755122], dtype=float32),
#   'probabilities': array([ 0.84909892,  0.15090108], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41645503], dtype=float32),
#   'logits': array([-0.33734298], dtype=float32),
#   'probabilities': array([ 0.58354497,  0.41645506], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.71330136], dtype=float32),
#   'logits': array([ 0.91147244], dtype=float32),
#   'probabilities': array([ 0.28669861,  0.71330136], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.56129277], dtype=float32),
#   'logits': array([ 0.24641025], dtype=float32),
#   'probabilities': array([ 0.43870726,  0.56129277], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40166524], dtype=float32),
#   'logits': array([-0.39853144], dtype=float32),
#   'probabilities': array([ 0.59833479,  0.40166524], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59059268], dtype=float32),
#   'logits': array([ 0.3664161], dtype=float32),
#   'probabilities': array([ 0.40940729,  0.59059268], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22962296], dtype=float32),
#   'logits': array([-1.21044147], dtype=float32),
#   'probabilities': array([ 0.77037704,  0.22962295], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21115129], dtype=float32),
#   'logits': array([-1.31799972], dtype=float32),
#   'probabilities': array([ 0.78884876,  0.21115129], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14240509], dtype=float32),
#   'logits': array([-1.79545605], dtype=float32),
#   'probabilities': array([ 0.85759485,  0.14240509], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28365925], dtype=float32),
#   'logits': array([-0.92638224], dtype=float32),
#   'probabilities': array([ 0.71634072,  0.28365925], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.48973957], dtype=float32),
#   'logits': array([-0.04104757], dtype=float32),
#   'probabilities': array([ 0.5102604 ,  0.48973951], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.70900381], dtype=float32),
#   'logits': array([ 0.89055061], dtype=float32),
#   'probabilities': array([ 0.29099622,  0.70900381], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24360681], dtype=float32),
#   'logits': array([-1.13300598], dtype=float32),
#   'probabilities': array([ 0.75639319,  0.24360678], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16943718], dtype=float32),
#   'logits': array([-1.58962131], dtype=float32),
#   'probabilities': array([ 0.83056283,  0.16943718], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42831931], dtype=float32),
#   'logits': array([-0.28871161], dtype=float32),
#   'probabilities': array([ 0.57168067,  0.42831931], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26076794], dtype=float32),
#   'logits': array([-1.0419811], dtype=float32),
#   'probabilities': array([ 0.73923212,  0.26076794], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16203977], dtype=float32),
#   'logits': array([-1.64312875], dtype=float32),
#   'probabilities': array([ 0.83796024,  0.16203979], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19607361], dtype=float32),
#   'logits': array([-1.41101754], dtype=float32),
#   'probabilities': array([ 0.80392641,  0.19607362], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12812151], dtype=float32),
#   'logits': array([-1.91767097], dtype=float32),
#   'probabilities': array([ 0.8718785 ,  0.12812151], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41639662], dtype=float32),
#   'logits': array([-0.33758336], dtype=float32),
#   'probabilities': array([ 0.58360338,  0.41639665], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.78789496], dtype=float32),
#   'logits': array([ 1.31228316], dtype=float32),
#   'probabilities': array([ 0.21210504,  0.78789496], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.79460216], dtype=float32),
#   'logits': array([ 1.35289299], dtype=float32),
#   'probabilities': array([ 0.2053978 ,  0.79460216], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59299719], dtype=float32),
#   'logits': array([ 0.3763696], dtype=float32),
#   'probabilities': array([ 0.40700281,  0.59299719], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49854049], dtype=float32),
#   'logits': array([-0.00583816], dtype=float32),
#   'probabilities': array([ 0.50145954,  0.49854046], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57249761], dtype=float32),
#   'logits': array([ 0.29204881], dtype=float32),
#   'probabilities': array([ 0.42750233,  0.57249761], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1271186], dtype=float32),
#   'logits': array([-1.92667913], dtype=float32),
#   'probabilities': array([ 0.87288135,  0.1271186 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5479939], dtype=float32),
#   'logits': array([ 0.19256842], dtype=float32),
#   'probabilities': array([ 0.4520061,  0.5479939], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.77949321], dtype=float32),
#   'logits': array([ 1.26271546], dtype=float32),
#   'probabilities': array([ 0.22050682,  0.77949321], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43591636], dtype=float32),
#   'logits': array([-0.25775212], dtype=float32),
#   'probabilities': array([ 0.56408364,  0.43591636], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29183084], dtype=float32),
#   'logits': array([-0.8865087], dtype=float32),
#   'probabilities': array([ 0.70816916,  0.29183084], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38568863], dtype=float32),
#   'logits': array([-0.46547157], dtype=float32),
#   'probabilities': array([ 0.6143114 ,  0.38568863], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62413919], dtype=float32),
#   'logits': array([ 0.50715446], dtype=float32),
#   'probabilities': array([ 0.37586084,  0.62413919], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26896989], dtype=float32),
#   'logits': array([-0.99985522], dtype=float32),
#   'probabilities': array([ 0.73103011,  0.26896989], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.68030459], dtype=float32),
#   'logits': array([ 0.7551719], dtype=float32),
#   'probabilities': array([ 0.31969541,  0.68030459], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41169697], dtype=float32),
#   'logits': array([-0.35695469], dtype=float32),
#   'probabilities': array([ 0.58830303,  0.41169691], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41885841], dtype=float32),
#   'logits': array([-0.32746154], dtype=float32),
#   'probabilities': array([ 0.58114159,  0.41885841], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1840688], dtype=float32),
#   'logits': array([-1.48902047], dtype=float32),
#   'probabilities': array([ 0.8159312,  0.1840688], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20613229], dtype=float32),
#   'logits': array([-1.34839869], dtype=float32),
#   'probabilities': array([ 0.79386771,  0.20613229], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19557184], dtype=float32),
#   'logits': array([-1.41420388], dtype=float32),
#   'probabilities': array([ 0.80442816,  0.19557184], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.45946535], dtype=float32),
#   'logits': array([-0.16249502], dtype=float32),
#   'probabilities': array([ 0.54053462,  0.45946538], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16599162], dtype=float32),
#   'logits': array([-1.61430621], dtype=float32),
#   'probabilities': array([ 0.8340084,  0.1659916], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.75978893], dtype=float32),
#   'logits': array([ 1.15152299], dtype=float32),
#   'probabilities': array([ 0.240211  ,  0.75978893], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23441572], dtype=float32),
#   'logits': array([-1.18354321], dtype=float32),
#   'probabilities': array([ 0.76558429,  0.23441572], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54017889], dtype=float32),
#   'logits': array([ 0.16106296], dtype=float32),
#   'probabilities': array([ 0.45982108,  0.54017889], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17117009], dtype=float32),
#   'logits': array([-1.57735717], dtype=float32),
#   'probabilities': array([ 0.82882988,  0.17117009], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.70812786], dtype=float32),
#   'logits': array([ 0.88630879], dtype=float32),
#   'probabilities': array([ 0.29187214,  0.70812786], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34081843], dtype=float32),
#   'logits': array([-0.65964913], dtype=float32),
#   'probabilities': array([ 0.65918159,  0.34081843], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21562953], dtype=float32),
#   'logits': array([-1.29131973], dtype=float32),
#   'probabilities': array([ 0.78437048,  0.21562952], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3571918], dtype=float32),
#   'logits': array([-0.58757341], dtype=float32),
#   'probabilities': array([ 0.64280814,  0.35719183], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36199299], dtype=float32),
#   'logits': array([-0.56672454], dtype=float32),
#   'probabilities': array([ 0.63800699,  0.36199296], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17650487], dtype=float32),
#   'logits': array([-1.54020917], dtype=float32),
#   'probabilities': array([ 0.82349515,  0.17650487], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.72725761], dtype=float32),
#   'logits': array([ 0.98075306], dtype=float32),
#   'probabilities': array([ 0.27274239,  0.72725761], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21037264], dtype=float32),
#   'logits': array([-1.32268071], dtype=float32),
#   'probabilities': array([ 0.78962737,  0.21037264], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18236299], dtype=float32),
#   'logits': array([-1.50041926], dtype=float32),
#   'probabilities': array([ 0.81763697,  0.18236299], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26779887], dtype=float32),
#   'logits': array([-1.00581908], dtype=float32),
#   'probabilities': array([ 0.73220116,  0.26779887], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4496561], dtype=float32),
#   'logits': array([-0.20206022], dtype=float32),
#   'probabilities': array([ 0.55034387,  0.4496561 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2858499], dtype=float32),
#   'logits': array([-0.91562629], dtype=float32),
#   'probabilities': array([ 0.71415007,  0.2858499 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12513031], dtype=float32),
#   'logits': array([-1.94471931], dtype=float32),
#   'probabilities': array([ 0.87486976,  0.12513031], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.84984368], dtype=float32),
#   'logits': array([ 1.73337519], dtype=float32),
#   'probabilities': array([ 0.15015636,  0.84984368], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.72389805], dtype=float32),
#   'logits': array([ 0.96388042], dtype=float32),
#   'probabilities': array([ 0.27610195,  0.72389805], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55553454], dtype=float32),
#   'logits': array([ 0.22305846], dtype=float32),
#   'probabilities': array([ 0.44446546,  0.55553454], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73505259], dtype=float32),
#   'logits': array([ 1.02041042], dtype=float32),
#   'probabilities': array([ 0.2649475 ,  0.73505259], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11065281], dtype=float32),
#   'logits': array([-2.08409023], dtype=float32),
#   'probabilities': array([ 0.8893472 ,  0.11065281], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16690466], dtype=float32),
#   'logits': array([-1.60772538], dtype=float32),
#   'probabilities': array([ 0.83309537,  0.16690466], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22182737], dtype=float32),
#   'logits': array([-1.25504887], dtype=float32),
#   'probabilities': array([ 0.77817261,  0.22182739], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35626245], dtype=float32),
#   'logits': array([-0.59162354], dtype=float32),
#   'probabilities': array([ 0.64373755,  0.35626242], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42238736], dtype=float32),
#   'logits': array([-0.31298053], dtype=float32),
#   'probabilities': array([ 0.57761264,  0.42238739], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59852546], dtype=float32),
#   'logits': array([ 0.39932501], dtype=float32),
#   'probabilities': array([ 0.40147454,  0.59852546], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5613355], dtype=float32),
#   'logits': array([ 0.24658394], dtype=float32),
#   'probabilities': array([ 0.4386645,  0.5613355], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39257064], dtype=float32),
#   'logits': array([-0.43651932], dtype=float32),
#   'probabilities': array([ 0.60742939,  0.39257067], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36798173], dtype=float32),
#   'logits': array([-0.54088503], dtype=float32),
#   'probabilities': array([ 0.63201827,  0.3679817 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37938604], dtype=float32),
#   'logits': array([-0.4921549], dtype=float32),
#   'probabilities': array([ 0.62061393,  0.37938607], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20239638], dtype=float32),
#   'logits': array([-1.37138367], dtype=float32),
#   'probabilities': array([ 0.79760361,  0.20239638], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.66056943], dtype=float32),
#   'logits': array([ 0.66583264], dtype=float32),
#   'probabilities': array([ 0.33943063,  0.66056943], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13134392], dtype=float32),
#   'logits': array([-1.88912809], dtype=float32),
#   'probabilities': array([ 0.86865604,  0.13134392], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26404628], dtype=float32),
#   'logits': array([-1.02504277], dtype=float32),
#   'probabilities': array([ 0.73595369,  0.26404628], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55015647], dtype=float32),
#   'logits': array([ 0.20130289], dtype=float32),
#   'probabilities': array([ 0.44984356,  0.55015647], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3811805], dtype=float32),
#   'logits': array([-0.48454058], dtype=float32),
#   'probabilities': array([ 0.61881948,  0.38118052], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20706776], dtype=float32),
#   'logits': array([-1.34269178], dtype=float32),
#   'probabilities': array([ 0.79293227,  0.20706774], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29331934], dtype=float32),
#   'logits': array([-0.87931705], dtype=float32),
#   'probabilities': array([ 0.70668072,  0.29331934], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30572984], dtype=float32),
#   'logits': array([-0.82015932], dtype=float32),
#   'probabilities': array([ 0.69427013,  0.30572984], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14549546], dtype=float32),
#   'logits': array([-1.77037692], dtype=float32),
#   'probabilities': array([ 0.85450459,  0.14549547], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19338967], dtype=float32),
#   'logits': array([-1.42813349], dtype=float32),
#   'probabilities': array([ 0.80661035,  0.19338968], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60642529], dtype=float32),
#   'logits': array([ 0.43231058], dtype=float32),
#   'probabilities': array([ 0.39357474,  0.60642529], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.71461451], dtype=float32),
#   'logits': array([ 0.91790235], dtype=float32),
#   'probabilities': array([ 0.28538552,  0.71461451], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.63933551], dtype=float32),
#   'logits': array([ 0.57248127], dtype=float32),
#   'probabilities': array([ 0.36066449,  0.63933551], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.72628289], dtype=float32),
#   'logits': array([ 0.97584426], dtype=float32),
#   'probabilities': array([ 0.27371716,  0.72628289], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46834046], dtype=float32),
#   'logits': array([-0.12680781], dtype=float32),
#   'probabilities': array([ 0.53165954,  0.46834046], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29553774], dtype=float32),
#   'logits': array([-0.86863828], dtype=float32),
#   'probabilities': array([ 0.70446229,  0.29553774], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52490348], dtype=float32),
#   'logits': array([ 0.0996964], dtype=float32),
#   'probabilities': array([ 0.47509652,  0.52490348], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19689177], dtype=float32),
#   'logits': array([-1.40583527], dtype=float32),
#   'probabilities': array([ 0.80310822,  0.19689177], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15251969], dtype=float32),
#   'logits': array([-1.71497393], dtype=float32),
#   'probabilities': array([ 0.84748036,  0.1525197 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20427608], dtype=float32),
#   'logits': array([-1.35977983], dtype=float32),
#   'probabilities': array([ 0.79572392,  0.20427608], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5360254], dtype=float32),
#   'logits': array([ 0.14435172], dtype=float32),
#   'probabilities': array([ 0.4639746,  0.5360254], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.06588777], dtype=float32),
#   'logits': array([-2.65164375], dtype=float32),
#   'probabilities': array([ 0.93411225,  0.06588777], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30730754], dtype=float32),
#   'logits': array([-0.81273723], dtype=float32),
#   'probabilities': array([ 0.69269252,  0.30730754], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17868592], dtype=float32),
#   'logits': array([-1.52527595], dtype=float32),
#   'probabilities': array([ 0.8213141 ,  0.17868592], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2675353], dtype=float32),
#   'logits': array([-1.00716364], dtype=float32),
#   'probabilities': array([ 0.73246473,  0.2675353 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26436162], dtype=float32),
#   'logits': array([-1.02342069], dtype=float32),
#   'probabilities': array([ 0.73563838,  0.26436162], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29580885], dtype=float32),
#   'logits': array([-0.86733639], dtype=float32),
#   'probabilities': array([ 0.70419115,  0.29580882], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.78935534], dtype=float32),
#   'logits': array([ 1.32104409], dtype=float32),
#   'probabilities': array([ 0.21064462,  0.78935534], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18718593], dtype=float32),
#   'logits': array([-1.4684], dtype=float32),
#   'probabilities': array([ 0.81281412,  0.18718594], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12983216], dtype=float32),
#   'logits': array([-1.90244353], dtype=float32),
#   'probabilities': array([ 0.87016785,  0.12983218], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61039203], dtype=float32),
#   'logits': array([ 0.44896042], dtype=float32),
#   'probabilities': array([ 0.38960797,  0.61039203], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.48857978], dtype=float32),
#   'logits': array([-0.04568899], dtype=float32),
#   'probabilities': array([ 0.51142031,  0.48857978], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.86304879], dtype=float32),
#   'logits': array([ 1.84084642], dtype=float32),
#   'probabilities': array([ 0.13695122,  0.86304879], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.6532529], dtype=float32),
#   'logits': array([ 0.63336861], dtype=float32),
#   'probabilities': array([ 0.3467471,  0.6532529], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13205558], dtype=float32),
#   'logits': array([-1.88290477], dtype=float32),
#   'probabilities': array([ 0.86794442,  0.13205558], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67685062], dtype=float32),
#   'logits': array([ 0.73933578], dtype=float32),
#   'probabilities': array([ 0.32314941,  0.67685062], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5841971], dtype=float32),
#   'logits': array([ 0.34002697], dtype=float32),
#   'probabilities': array([ 0.41580293,  0.5841971 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.80741131], dtype=float32),
#   'logits': array([ 1.4332763], dtype=float32),
#   'probabilities': array([ 0.19258873,  0.80741131], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24530143], dtype=float32),
#   'logits': array([-1.1238308], dtype=float32),
#   'probabilities': array([ 0.75469863,  0.24530141], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18142711], dtype=float32),
#   'logits': array([-1.5067085], dtype=float32),
#   'probabilities': array([ 0.81857288,  0.18142709], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.56702602], dtype=float32),
#   'logits': array([ 0.26972759], dtype=float32),
#   'probabilities': array([ 0.43297398,  0.56702602], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17199701], dtype=float32),
#   'logits': array([-1.57153964], dtype=float32),
#   'probabilities': array([ 0.82800305,  0.17199703], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.78511852], dtype=float32),
#   'logits': array([ 1.29574788], dtype=float32),
#   'probabilities': array([ 0.21488151,  0.78511852], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57589656], dtype=float32),
#   'logits': array([ 0.30595064], dtype=float32),
#   'probabilities': array([ 0.42410344,  0.57589656], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18651983], dtype=float32),
#   'logits': array([-1.47278392], dtype=float32),
#   'probabilities': array([ 0.81348014,  0.18651983], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.58027899], dtype=float32),
#   'logits': array([ 0.32391882], dtype=float32),
#   'probabilities': array([ 0.41972098,  0.58027899], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.48070565], dtype=float32),
#   'logits': array([-0.07721567], dtype=float32),
#   'probabilities': array([ 0.51929432,  0.48070565], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11544957], dtype=float32),
#   'logits': array([-2.03624582], dtype=float32),
#   'probabilities': array([ 0.88455051,  0.11544957], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.56421417], dtype=float32),
#   'logits': array([ 0.25828302], dtype=float32),
#   'probabilities': array([ 0.43578583,  0.56421417], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59740424], dtype=float32),
#   'logits': array([ 0.39466107], dtype=float32),
#   'probabilities': array([ 0.40259576,  0.59740424], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.77295643], dtype=float32),
#   'logits': array([ 1.22508085], dtype=float32),
#   'probabilities': array([ 0.22704355,  0.77295643], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.82144451], dtype=float32),
#   'logits': array([ 1.52616489], dtype=float32),
#   'probabilities': array([ 0.17855552,  0.82144451], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.45148692], dtype=float32),
#   'logits': array([-0.19466472], dtype=float32),
#   'probabilities': array([ 0.54851305,  0.45148689], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17915483], dtype=float32),
#   'logits': array([-1.52208412], dtype=float32),
#   'probabilities': array([ 0.82084525,  0.17915484], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.09199911], dtype=float32),
#   'logits': array([-2.28946638], dtype=float32),
#   'probabilities': array([ 0.90800089,  0.09199911], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1115974], dtype=float32),
#   'logits': array([-2.07452726], dtype=float32),
#   'probabilities': array([ 0.88840258,  0.11159739], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28118077], dtype=float32),
#   'logits': array([-0.93861204], dtype=float32),
#   'probabilities': array([ 0.7188192 ,  0.28118077], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34529465], dtype=float32),
#   'logits': array([-0.63978708], dtype=float32),
#   'probabilities': array([ 0.65470529,  0.34529465], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2998541], dtype=float32),
#   'logits': array([-0.84799266], dtype=float32),
#   'probabilities': array([ 0.70014584,  0.2998541 ], dtype=float32)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/9s/5vz1zfb95wz07q4_m6h5bg8w0000gn/T/tmpb_ktc4ao
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/9s/5vz1zfb95wz07q4_m6h5bg8w0000gn/T/tmpb_ktc4ao', '_tf_random_seed': 1, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100}

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-0acf193fb5de> in <module>()
#       1 # UH OH! AN ERROR. Check out the video to see why and how to fix.
#       2 # https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
# ----> 3 dnn_model.train(input_fn=input_func,steps=1000)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps)
#     239       hooks.append(training.StopAtStepHook(steps, max_steps))
#     240
# --> 241     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#     242     logging.info('Loss for final step: %s.', loss)
#     243     return self
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks)
#     628           input_fn, model_fn_lib.ModeKeys.TRAIN)
#     629       estimator_spec = self._call_model_fn(features, labels,
# --> 630                                            model_fn_lib.ModeKeys.TRAIN)
#     631       ops.add_to_collection(ops.GraphKeys.LOSSES, estimator_spec.loss)
#     632       all_hooks.extend(hooks)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode)
#     613     if 'config' in model_fn_args:
#     614       kwargs['config'] = self.config
# --> 615     model_fn_results = self._model_fn(features=features, **kwargs)
#     616
#     617     if not isinstance(model_fn_results, model_fn_lib.EstimatorSpec):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/canned/dnn.py in _model_fn(features, labels, mode, config)
#     269           dropout=dropout,
#     270           input_layer_partitioner=input_layer_partitioner,
# --> 271           config=config)
#     272     super(DNNClassifier, self).__init__(
#     273         model_fn=_model_fn, model_dir=model_dir, config=config)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/canned/dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config)
#     100       net = feature_column_lib.input_layer(
#     101           features=features,
# --> 102           feature_columns=feature_columns)
#     103
#     104     for layer_id, num_hidden_units in enumerate(hidden_units):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in input_layer(features, feature_columns, weight_collections, trainable)
#     211           'Items of feature_columns must be a _DenseColumn. '
#     212           'You can wrap a categorical column with an '
# --> 213           'embedding_column or indicator_column. Given: {}'.format(column))
#     214   weight_collections = list(weight_collections or [])
#     215   if ops.GraphKeys.GLOBAL_VARIABLES not in weight_collections:
#
# ValueError: Items of feature_columns must be a _DenseColumn. You can wrap a categorical column with an embedding_column or indicator_column. Given: _VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)

# %%
dnn_model.train(input_fn=input_func,steps=1000)

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)

# %% [markdown]
# # Great Job!
